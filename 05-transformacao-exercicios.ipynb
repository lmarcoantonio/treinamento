# %% [markdown]
# # Aula 05 - Exercícios
#
# Resolva os exercícios nos campos indicados.
#
# ## Ajustes

# %%
home <- path.expand("~")
lib_dir <- file.path(file.path(home, "R"), "lib")
dir.create(lib_dir, showWarnings = FALSE)

library(utils)
.libPaths(c(lib_dir, .libPaths()))

# libraries needed
install.packages("tidyverse")
library(tidyverse)

install.packages("ukbabynames")
library(ukbabynames)

set.seed(777) # makes sure random numbers are reproducible
# Out:
# The downloaded binary packages are in
# 	/var/folders/pj/q06rg07s0ylcwm8vw7s2s6lc0000gp/T//RtmpvSNKXK/downloaded_packages
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.3
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   1.0.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# The downloaded binary packages are in
# 	/var/folders/pj/q06rg07s0ylcwm8vw7s2s6lc0000gp/T//RtmpvSNKXK/downloaded_packages

# %% [markdown]
# ## Nomes de bebê no Reino Unido
#
# Vamos converter a tabela do pacote _ukbabynames_ para um tibble e atribuir o resultado à variável `ukb`. Utilize o tibble para as questões 1-13.

# %%
ukb <- as_tibble(ukbabynames) # convert to a tibble

# %% [markdown]
# ### Questão 5.1
#
# Quantos registros o dataset possui?

# %%
# Escreva aqui a resposta. A saída deve ser a mesma
# Out:
# [1] 227449

# %% [markdown]
# ### Questão 5.2
#
# Remova a coluna `rank` do dataset.

# %%
# Escreva aqui a resposta. A saída deve ser a mesma
# Out:
#        year sex name       n
# 1      1996 F   Sophie     7087
# 2      1996 F   Chloe      6824
# 3      1996 F   Jessica    6711
# 4      1996 F   Emily      6415
# 5      1996 F   Lauren     6299
# 6      1996 F   Hannah     5916
# 7      1996 F   Charlotte  5866
# 8      1996 F   Rebecca    5828
# 9      1996 F   Amy        5206
# 10     1996 F   Megan      4948
# 11     1996 F   Shannon    4649
# 12     1996 F   Katie      4337
# 13     1996 F   Bethany    4271
# 14     1996 F   Emma       4232
# 15     1996 F   Lucy       3753
# 16     1996 F   Georgia    3723
# 17     1996 F   Laura      3582
# 18     1996 F   Sarah      3111
# 19     1996 F   Jade       2750
# 20     1996 F   Danielle   2641
# 21     1996 F   Abigail    2595
# 22     1996 F   Eleanor    2555
# 23     1996 F   Holly      2498
# 24     1996 F   Olivia     2456
# 25     1996 F   Alice      2357
# 26     1996 F   Elizabeth  2225
# 27     1996 F   Rachel     2105
# 28     1996 F   Paige      2052
# ...

# %% [markdown]
# ### Questão 5.3
#
# Qual é o intervalo de anos de nascimento presente no dataset? Utilize a função `summarise` para construir uma tabela com duas colunas: `minyear` e `maxyear`.

# %%
# Escreva aqui a resposta. A saída deve ser a mesma
# Out:
#   minyear maxyear
# 1 1996    2015

# %% [markdown]
# ### Questão 5.4
#
# Faça uma tabela contendo somente os nomes de bebê que se chamam "Hermione".

# %%
# Escreva aqui a resposta. A saída deve ser a mesma
# Out:
#    year sex name     n   rank
# 1  1996 F   Hermione  21 974
# 2  1997 F   Hermione  29 789
# 3  1998 F   Hermione  40 628
# 4  1999 F   Hermione  35 678
# 5  2000 F   Hermione  40 637
# 6  2001 F   Hermione  52 540
# 7  2002 F   Hermione  84 394
# 8  2003 F   Hermione 158 265
# 9  2004 F   Hermione 162 265
# 10 2005 F   Hermione 122 331
# 11 2006 F   Hermione 118 359
# 12 2007 F   Hermione 109 385
# 13 2008 F   Hermione 129 348
# 14 2009 F   Hermione 116 370
# 15 2010 F   Hermione 111 398
# 16 2011 F   Hermione 118 392
# 17 2012 F   Hermione  97 465
# 18 2013 F   Hermione  77 542
# 19 2014 F   Hermione  85 500
# 20 2015 F   Hermione  79 549

# %% [markdown]
# ### Questão 5.5
#
# Ordene o dataset por sexo e depois por ano (descendente). Depois ordene por ranking (descendente)

# %%
# Escreva aqui a resposta. A saída deve ser a mesma
# Out:
#        year sex name        n     rank
# 1      2015 F   Aabidah     3     5730
# 2      2015 F   Aabish      3     5730
# 3      2015 F   Aaeesha     3     5730
# 4      2015 F   Aafreen     3     5730
# 5      2015 F   Aaiza       3     5730
# 6      2015 F   Aakifa      3     5730
# 7      2015 F   Aala        3     5730
# 8      2015 F   Aaliyah-Mai 3     5730
# 9      2015 F   Aaliyah-may 3     5730
# 10     2015 F   Aamena      3     5730
# 11     2015 F   Aamirah     3     5730
# 12     2015 F   Aanaya      3     5730
# 13     2015 F   Aanika      3     5730
# 14     2015 F   Aarathana   3     5730
# 15     2015 F   Aarifa      3     5730
# 16     2015 F   Aarifah     3     5730
# 17     2015 F   Aaryana     3     5730
# 18     2015 F   Aastha      3     5730
# 19     2015 F   Aayana      3     5730
# 20     2015 F   Aayliah     3     5730
# 21     2015 F   Aayrah      3     5730
# 22     2015 F   Aazeen      3     5730
# 23     2015 F   Abbie-Mae   3     5730
# ...

# %% [markdown]
# ### Questão 5.6
#
# Crie uma nova coluna chamada `decade` contendo a década do nascimento (1990, 2000 e 2010). Dica: pesquise a função `floor`.

# %%
# Escreva aqui a resposta. A saída deve ser a mesma
# Out:
#        year sex name       n    rank decade
# 1      1996 F   Sophie     7087  1   1990
# 2      1996 F   Chloe      6824  2   1990
# 3      1996 F   Jessica    6711  3   1990
# 4      1996 F   Emily      6415  4   1990
# 5      1996 F   Lauren     6299  5   1990
# 6      1996 F   Hannah     5916  6   1990
# 7      1996 F   Charlotte  5866  7   1990
# 8      1996 F   Rebecca    5828  8   1990
# 9      1996 F   Amy        5206  9   1990
# 10     1996 F   Megan      4948 10   1990
# 11     1996 F   Shannon    4649 11   1990
# 12     1996 F   Katie      4337 12   1990
# 13     1996 F   Bethany    4271 13   1990
# 14     1996 F   Emma       4232 14   1990
# 15     1996 F   Lucy       3753 15   1990
# 16     1996 F   Georgia    3723 16   1990
# 17     1996 F   Laura      3582 17   1990
# 18     1996 F   Sarah      3111 18   1990
# 19     1996 F   Jade       2750 19   1990
# 20     1996 F   Danielle   2641 20   1990
# 21     1996 F   Abigail    2595 21   1990
# ...

# %% [markdown]
# ### Questão 5.7
#
# Crie uma nova coluna contendo somente os dados dos bebês do sexo masculino chamados "Courtney" nascidos entre 1998 e 2001 (inclusive).

# %%
# Escreva aqui a resposta. A saída deve ser a mesma
# Out:
#   year sex name     n  rank
# 1 1998 M   Courtney 33 554
# 2 1999 M   Courtney 15 973
# 3 2000 M   Courtney 19 848
# 4 2001 M   Courtney 22 786

# %% [markdown]
# ### Questão 5.8
#
# Quantos nomes únicos o dataset contém? Garanta que o resultado é um inteiro, e não um dataset.

# %%
# Escreva aqui a resposta. A saída deve ser a mesma
# Out:
# [1] 31272

# %% [markdown]
# ### Questão 5.9
#
# Construa uma tabela contendo somente os dados dos bebês do sexo feminino chamados "Frankie" que nasceram entre 1999 e 2010.

# %%
# Escreva aqui a resposta. A saída deve ser a mesma
# Out:
#   year sex name    n   rank
# 1 1996 F   Frankie  34 686
# 2 1997 F   Frankie  48 545
# 3 1998 F   Frankie  41 619
# 4 2011 F   Frankie 337 156
# 5 2012 F   Frankie 298 173
# 6 2013 F   Frankie 273 195
# 7 2014 F   Frankie 344 162
# 8 2015 F   Frankie 376 147

# %% [markdown]
# ### Questão 5.10
#
# Quantos bebês no dataset são chamados "Emily"? Garanta que `emily` é um inteiro, e não uma tabela.

# %%
# Escreva aqui a resposta. A saída deve ser a mesma
# Out:
# [1] 102250

# %% [markdown]
# ### Questão 5.11
#
# Quantos nomes únicos para cada sexo?

# %%
# Escreva aqui a resposta. A saída deve ser a mesma
# Out:
#   sex n
# 1 F   18823
# 2 M   14378

# %% [markdown]
# ### Questão 5.12
#
# Qual é o nome mais popular do dataset?

# %%
# Escreva aqui a resposta. A saída deve ser a mesma
# Out:
# [1] "Jack"

# %% [markdown]
# ### Questão 5.13
#
# Quantos bebês foram nascidos em cada ano por sexo? Construa um gráfico.

# %%
# Escreva aqui a resposta. A saída deve ser a mesma
# Out:
#    year sex tot
# 1  1996 F   295998
# 2  1996 M   318517
# 3  1997 F   293182
# 4  1997 M   314454
# 5  1998 F   289184
# 6  1998 M   310474
# 7  1999 F   281697
# 8  1999 M   303241
# 9  2000 F   273174
# 10 2000 M   293185
# 11 2001 F   267994
# 12 2001 M   287837
# 13 2002 F   267367
# 14 2002 M   288313
# 15 2003 F   278670
# 16 2003 M   299560
# 17 2004 F   285859
# 18 2004 M   308516
# 19 2005 F   288257
# 20 2005 M   309480
# 21 2006 F   299238
# 22 2006 M   320360
# 23 2007 F   306123
# 24 2007 M   331373
# 25 2008 F   315764
# 26 2008 M   339407
# 27 2009 F   313380
# 28 2009 M   338173
# 29 2010 F   321041
# 30 2010 M   346299
# 31 2011 F   321315
# 32 2011 M   345915
# 33 2012 F   322063
# 34 2012 M   348459
# 35 2013 F   308456
# 36 2013 M   333629
# 37 2014 F   306668
# 38 2014 M   332184
# 39 2015 F   307935
# 40 2015 M   333281
# plot without title
